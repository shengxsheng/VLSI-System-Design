# %% [markdown]
# # HW2: Model Inference of the Pretrained LeNet

# %% [markdown]
# <font color='white'>Name: 潘金生
# Student ID: 112061533 </font>

# %% [markdown]
# ## 0. Initial Setup
# * Currently, Numba does not support Python 3.10 or higher versions. Therefore, if you are using Python versions 3.10 and above, **please downgrade to a lower version or switch to running it on Colab**
# * If errors occur, it may be due to incompatibility between the versions of NumPy and Numba. You can try adding `!pip install numpy==1.18`. If the issue persists, consider switching to running it on Colab.

# %%
#Uncomment the following line if you are on your local machine and facing issues with numpy. Comment it if you are on colab
# !pip install numpy==1.18
# !pip install numba==0.55.1
# Out:
# Requirement already satisfied: numba==0.55.1 in /usr/local/lib/python3.10/dist-packages (0.55.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /usr/local/lib/python3.10/dist-packages (from numba==0.55.1) (0.38.1)
# Requirement already satisfied: numpy<1.22,>=1.18 in /usr/local/lib/python3.10/dist-packages (from numba==0.55.1) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba==0.55.1) (67.7.2)

# %%
import torch
from torch.utils.data import DataLoader
import torchvision
import torchvision.transforms as transforms
import json
import numpy as np
from functional import *

# %% [markdown]
# ## 1. High-level Function Implementation for Each Layer
# Implement a high-level functional model for each layer of the CNN, including convolution, pooling, and
# fully-connected layer with 8-bit quantization of the input activations, output activations, and weights accordingly.
# * Learn how to use [Numba](https://numba.pydata.org/) to accelerate python functions
# * Fill in the TODOs in `functional.py`.
#     * You must consider `psum_range = (lower_bound, upper_bound)` which controls the precision of partial sums. That means the accumulation of activations will not exceed this range during the process of computing convolution and fully-connected layers.
#     * `psum_record_list` will be used in *2. Bit-width of Partial Sums*, so you may leave it alone for now.
#
# ### 1.1 Pass all Unit Tests of `OpTestCase`.
# First, use 32-bit signed integers for the partial sums to pass the unit tests. The accumulation of activations is limited to 32 bits in convolution and fully-connected layers. Clamp the value if it exceeds the minimum or maximum values of the 32-bit signed number.
#
# Note that you should implement convolution layers, fully-connected layers, and max-pooling layers with "nested loops" by yourself. You are not allowed to use existing functions (e.g., `conv2d` in `numpy` or `pytorch`). Or you will not get any credits. Raise questions when in doubt.
#
# There are eight unit tests you need to pass. If you intend to run part of them, follow the steps:
# ```
# tests = ['test_C1', 'test_C3']
# suite = unittest.TestSuite(map(OpTestCase, tests))
# ```

# %%
#unzip parameters.zip if needed
# !unzip /content/parameters.zip
# Out:
# Archive:  /content/parameters.zip
#   inflating: weights/conv1.conv.weight.csv
#   inflating: weights/conv3.conv.weight.csv
#   inflating: weights/conv5.conv.weight.csv
#   inflating: weights/fc6.fc.weight.csv
#   inflating: weights/output.fc.weight.csv
#   inflating: fixed_scale.json
#   inflating: weights/output.fc.bias.csv
#   inflating: activations/img0/input.csv
#   inflating: activations/img0/output.csv
#   inflating: activations/img0/conv1/input.csv
#   inflating: activations/img0/conv1/output.csv
#   inflating: activations/img0/maxpool2/input.csv
#   inflating: activations/img0/maxpool2/output.csv
#   inflating: activations/img0/conv3/input.csv
#   inflating: activations/img0/conv3/output.csv
#   inflating: activations/img0/maxpool4/input.csv
#   inflating: activations/img0/maxpool4/output.csv
#   inflating: activations/img0/conv5/input.csv
#   inflating: activations/img0/conv5/output.csv
#   inflating: activations/img0/fc6/input.csv
#   inflating: activations/img0/fc6/output.csv
#   inflating: activations/img0/output/input.csv
#   inflating: activations/img0/output/output.csv
#   inflating: activations/img1/input.csv
#   inflating: activations/img1/output.csv
#   inflating: activations/img1/conv1/input.csv
#   inflating: activations/img1/conv1/output.csv
#   inflating: activations/img1/maxpool2/input.csv
#   inflating: activations/img1/maxpool2/output.csv
#   inflating: activations/img1/conv3/input.csv
#   inflating: activations/img1/conv3/output.csv
#   inflating: activations/img1/maxpool4/input.csv
#   inflating: activations/img1/maxpool4/output.csv
#   inflating: activations/img1/conv5/input.csv
#   inflating: activations/img1/conv5/output.csv
#   inflating: activations/img1/fc6/input.csv
#   inflating: activations/img1/fc6/output.csv
#   inflating: activations/img1/output/input.csv
#   inflating: activations/img1/output/output.csv
#   inflating: activations/img2/input.csv
#   inflating: activations/img2/output.csv
#   inflating: activations/img2/conv1/input.csv
#   inflating: activations/img2/conv1/output.csv
#   inflating: activations/img2/maxpool2/input.csv
#   inflating: activations/img2/maxpool2/output.csv
#   inflating: activations/img2/conv3/input.csv
#   inflating: activations/img2/conv3/output.csv
#   inflating: activations/img2/maxpool4/input.csv
#   inflating: activations/img2/maxpool4/output.csv
#   inflating: activations/img2/conv5/input.csv
#   inflating: activations/img2/conv5/output.csv
#   inflating: activations/img2/fc6/input.csv
#   inflating: activations/img2/fc6/output.csv
#   inflating: activations/img2/output/input.csv
#   inflating: activations/img2/output/output.csv
#   inflating: activations/img3/input.csv
#   inflating: activations/img3/output.csv
#   inflating: activations/img3/conv1/input.csv
#   inflating: activations/img3/conv1/output.csv
#   inflating: activations/img3/maxpool2/input.csv
#   inflating: activations/img3/maxpool2/output.csv
#   inflating: activations/img3/conv3/input.csv
#   inflating: activations/img3/conv3/output.csv
#   inflating: activations/img3/maxpool4/input.csv
#   inflating: activations/img3/maxpool4/output.csv
#   inflating: activations/img3/conv5/input.csv
#   inflating: activations/img3/conv5/output.csv
#   inflating: activations/img3/fc6/input.csv
#   inflating: activations/img3/fc6/output.csv
#   inflating: activations/img3/output/input.csv
#   inflating: activations/img3/output/output.csv
#   inflating: activations/img4/input.csv
#   inflating: activations/img4/output.csv
#   inflating: activations/img4/conv1/input.csv
#   inflating: activations/img4/conv1/output.csv
#   inflating: activations/img4/maxpool2/input.csv
#   inflating: activations/img4/maxpool2/output.csv
#   inflating: activations/img4/conv3/input.csv
#   inflating: activations/img4/conv3/output.csv
#   inflating: activations/img4/maxpool4/input.csv
#   inflating: activations/img4/maxpool4/output.csv
#   inflating: activations/img4/conv5/input.csv
#   inflating: activations/img4/conv5/output.csv
#   inflating: activations/img4/fc6/input.csv
#   inflating: activations/img4/fc6/output.csv
#   inflating: activations/img4/output/input.csv
#   inflating: activations/img4/output/output.csv
#   inflating: activations/img5/input.csv
#   inflating: activations/img5/output.csv
#   inflating: activations/img5/conv1/input.csv
#   inflating: activations/img5/conv1/output.csv
#   inflating: activations/img5/maxpool2/input.csv
#   inflating: activations/img5/maxpool2/output.csv
#   inflating: activations/img5/conv3/input.csv
#   inflating: activations/img5/conv3/output.csv
#   inflating: activations/img5/maxpool4/input.csv
#   inflating: activations/img5/maxpool4/output.csv
#   inflating: activations/img5/conv5/input.csv
#   inflating: activations/img5/conv5/output.csv
#   inflating: activations/img5/fc6/input.csv
#   inflating: activations/img5/fc6/output.csv
#   inflating: activations/img5/output/input.csv
#   inflating: activations/img5/output/output.csv
#   inflating: activations/img6/input.csv
#   inflating: activations/img6/output.csv
#   inflating: activations/img6/conv1/input.csv
#   inflating: activations/img6/conv1/output.csv
#   inflating: activations/img6/maxpool2/input.csv
#   inflating: activations/img6/maxpool2/output.csv
#   inflating: activations/img6/conv3/input.csv
#   inflating: activations/img6/conv3/output.csv
#   inflating: activations/img6/maxpool4/input.csv
#   inflating: activations/img6/maxpool4/output.csv
#   inflating: activations/img6/conv5/input.csv
#   inflating: activations/img6/conv5/output.csv
#   inflating: activations/img6/fc6/input.csv
#   inflating: activations/img6/fc6/output.csv
#   inflating: activations/img6/output/input.csv
#   inflating: activations/img6/output/output.csv
#   inflating: activations/img7/input.csv
#   inflating: activations/img7/output.csv
#   inflating: activations/img7/conv1/input.csv
#   inflating: activations/img7/conv1/output.csv
#   inflating: activations/img7/maxpool2/input.csv
#   inflating: activations/img7/maxpool2/output.csv
#   inflating: activations/img7/conv3/input.csv
#   inflating: activations/img7/conv3/output.csv
#   inflating: activations/img7/maxpool4/input.csv
#   inflating: activations/img7/maxpool4/output.csv
#   inflating: activations/img7/conv5/input.csv
#   inflating: activations/img7/conv5/output.csv
#   inflating: activations/img7/fc6/input.csv
#   inflating: activations/img7/fc6/output.csv
#   inflating: activations/img7/output/input.csv
#   inflating: activations/img7/output/output.csv
#   inflating: activations/img8/input.csv
#   inflating: activations/img8/output.csv
#   inflating: activations/img8/conv1/input.csv
#   inflating: activations/img8/conv1/output.csv
#   inflating: activations/img8/maxpool2/input.csv
#   inflating: activations/img8/maxpool2/output.csv
#   inflating: activations/img8/conv3/input.csv
#   inflating: activations/img8/conv3/output.csv
#   inflating: activations/img8/maxpool4/input.csv
#   inflating: activations/img8/maxpool4/output.csv
#   inflating: activations/img8/conv5/input.csv
#   inflating: activations/img8/conv5/output.csv
#   inflating: activations/img8/fc6/input.csv
#   inflating: activations/img8/fc6/output.csv
#   inflating: activations/img8/output/input.csv
#   inflating: activations/img8/output/output.csv
#   inflating: activations/img9/input.csv
#   inflating: activations/img9/output.csv
#   inflating: activations/img9/conv1/input.csv
#   inflating: activations/img9/conv1/output.csv
#   inflating: activations/img9/maxpool2/input.csv
#   inflating: activations/img9/maxpool2/output.csv
#   inflating: activations/img9/conv3/input.csv
#   inflating: activations/img9/conv3/output.csv
#   inflating: activations/img9/maxpool4/input.csv
#   inflating: activations/img9/maxpool4/output.csv
#   inflating: activations/img9/conv5/input.csv
#   inflating: activations/img9/conv5/output.csv
#   inflating: activations/img9/fc6/input.csv
#   inflating: activations/img9/fc6/output.csv
#   inflating: activations/img9/output/input.csv
#   inflating: activations/img9/output/output.csv
#   inflating: activations/img10/input.csv
#   inflating: activations/img10/output.csv
#   inflating: activations/img10/conv1/input.csv
#   inflating: activations/img10/conv1/output.csv
#   inflating: activations/img10/maxpool2/input.csv
#   inflating: activations/img10/maxpool2/output.csv
#   inflating: activations/img10/conv3/input.csv
#   inflating: activations/img10/conv3/output.csv
#   inflating: activations/img10/maxpool4/input.csv
#   inflating: activations/img10/maxpool4/output.csv
#   inflating: activations/img10/conv5/input.csv
#   inflating: activations/img10/conv5/output.csv
#   inflating: activations/img10/fc6/input.csv
#   inflating: activations/img10/fc6/output.csv
#   inflating: activations/img10/output/input.csv
#   inflating: activations/img10/output/output.csv
#   inflating: activations/img11/input.csv
#   inflating: activations/img11/output.csv
#   inflating: activations/img11/conv1/input.csv
#   inflating: activations/img11/conv1/output.csv
#   inflating: activations/img11/maxpool2/input.csv
#   inflating: activations/img11/maxpool2/output.csv
#   inflating: activations/img11/conv3/input.csv
#   inflating: activations/img11/conv3/output.csv
#   inflating: activations/img11/maxpool4/input.csv
#   inflating: activations/img11/maxpool4/output.csv
#   inflating: activations/img11/conv5/input.csv
#   inflating: activations/img11/conv5/output.csv
#   inflating: activations/img11/fc6/input.csv
#   inflating: activations/img11/fc6/output.csv
#   inflating: activations/img11/output/input.csv
#   inflating: activations/img11/output/output.csv
#   inflating: activations/img12/input.csv
#   inflating: activations/img12/output.csv
#   inflating: activations/img12/conv1/input.csv
#   inflating: activations/img12/conv1/output.csv
#   inflating: activations/img12/maxpool2/input.csv
#   inflating: activations/img12/maxpool2/output.csv
#   inflating: activations/img12/conv3/input.csv
#   inflating: activations/img12/conv3/output.csv
#   inflating: activations/img12/maxpool4/input.csv
#   inflating: activations/img12/maxpool4/output.csv
#   inflating: activations/img12/conv5/input.csv
#   inflating: activations/img12/conv5/output.csv
#   inflating: activations/img12/fc6/input.csv
#   inflating: activations/img12/fc6/output.csv
#   inflating: activations/img12/output/input.csv
#   inflating: activations/img12/output/output.csv
#   inflating: activations/img13/input.csv
#   inflating: activations/img13/output.csv
#   inflating: activations/img13/conv1/input.csv
#   inflating: activations/img13/conv1/output.csv
#   inflating: activations/img13/maxpool2/input.csv
#   inflating: activations/img13/maxpool2/output.csv
#   inflating: activations/img13/conv3/input.csv
#   inflating: activations/img13/conv3/output.csv
#   inflating: activations/img13/maxpool4/input.csv
#   inflating: activations/img13/maxpool4/output.csv
#   inflating: activations/img13/conv5/input.csv
#   inflating: activations/img13/conv5/output.csv
#   inflating: activations/img13/fc6/input.csv
#   inflating: activations/img13/fc6/output.csv
#   inflating: activations/img13/output/input.csv
#   inflating: activations/img13/output/output.csv
#   inflating: activations/img14/input.csv
#   inflating: activations/img14/output.csv
#   inflating: activations/img14/conv1/input.csv
#   inflating: activations/img14/conv1/output.csv
#   inflating: activations/img14/maxpool2/input.csv
#   inflating: activations/img14/maxpool2/output.csv
#   inflating: activations/img14/conv3/input.csv
#   inflating: activations/img14/conv3/output.csv
#   inflating: activations/img14/maxpool4/input.csv
#   inflating: activations/img14/maxpool4/output.csv
#   inflating: activations/img14/conv5/input.csv
#   inflating: activations/img14/conv5/output.csv
#   inflating: activations/img14/fc6/input.csv
#   inflating: activations/img14/fc6/output.csv
#   inflating: activations/img14/output/input.csv
#   inflating: activations/img14/output/output.csv
#   inflating: activations/img15/input.csv
#   inflating: activations/img15/output.csv
#   inflating: activations/img15/conv1/input.csv
#   inflating: activations/img15/conv1/output.csv
#   inflating: activations/img15/maxpool2/input.csv
#   inflating: activations/img15/maxpool2/output.csv
#   inflating: activations/img15/conv3/input.csv
#   inflating: activations/img15/conv3/output.csv
#   inflating: activations/img15/maxpool4/input.csv
#   inflating: activations/img15/maxpool4/output.csv
#   inflating: activations/img15/conv5/input.csv
#   inflating: activations/img15/conv5/output.csv
#   inflating: activations/img15/fc6/input.csv
#   inflating: activations/img15/fc6/output.csv
#   inflating: activations/img15/output/input.csv
#   inflating: activations/img15/output/output.csv
#   inflating: activations/img16/input.csv
#   inflating: activations/img16/output.csv
#   inflating: activations/img16/conv1/input.csv
#   inflating: activations/img16/conv1/output.csv
#   inflating: activations/img16/maxpool2/input.csv
#   inflating: activations/img16/maxpool2/output.csv
#   inflating: activations/img16/conv3/input.csv
#   inflating: activations/img16/conv3/output.csv
#   inflating: activations/img16/maxpool4/input.csv
#   inflating: activations/img16/maxpool4/output.csv
#   inflating: activations/img16/conv5/input.csv
#   inflating: activations/img16/conv5/output.csv
#   inflating: activations/img16/fc6/input.csv
#   inflating: activations/img16/fc6/output.csv
#   inflating: activations/img16/output/input.csv
#   inflating: activations/img16/output/output.csv
#   inflating: activations/img17/input.csv
#   inflating: activations/img17/output.csv
#   inflating: activations/img17/conv1/input.csv
#   inflating: activations/img17/conv1/output.csv
#   inflating: activations/img17/maxpool2/input.csv
#   inflating: activations/img17/maxpool2/output.csv
#   inflating: activations/img17/conv3/input.csv
#   inflating: activations/img17/conv3/output.csv
#   inflating: activations/img17/maxpool4/input.csv
#   inflating: activations/img17/maxpool4/output.csv
#   inflating: activations/img17/conv5/input.csv
#   inflating: activations/img17/conv5/output.csv
#   inflating: activations/img17/fc6/input.csv
#   inflating: activations/img17/fc6/output.csv
#   inflating: activations/img17/output/input.csv
#   inflating: activations/img17/output/output.csv
#   inflating: activations/img18/input.csv
#   inflating: activations/img18/output.csv
#   inflating: activations/img18/conv1/input.csv
#   inflating: activations/img18/conv1/output.csv
#   inflating: activations/img18/maxpool2/input.csv
#   inflating: activations/img18/maxpool2/output.csv
#   inflating: activations/img18/conv3/input.csv
#   inflating: activations/img18/conv3/output.csv
#   inflating: activations/img18/maxpool4/input.csv
#   inflating: activations/img18/maxpool4/output.csv
#   inflating: activations/img18/conv5/input.csv
#   inflating: activations/img18/conv5/output.csv
#   inflating: activations/img18/fc6/input.csv
#   inflating: activations/img18/fc6/output.csv
#   inflating: activations/img18/output/input.csv
#   inflating: activations/img18/output/output.csv
#   inflating: activations/img19/input.csv
#   inflating: activations/img19/output.csv
#   inflating: activations/img19/conv1/input.csv
#   inflating: activations/img19/conv1/output.csv
#   inflating: activations/img19/maxpool2/input.csv
#   inflating: activations/img19/maxpool2/output.csv
#   inflating: activations/img19/conv3/input.csv
#   inflating: activations/img19/conv3/output.csv
#   inflating: activations/img19/maxpool4/input.csv
#   inflating: activations/img19/maxpool4/output.csv
#   inflating: activations/img19/conv5/input.csv
#   inflating: activations/img19/conv5/output.csv
#   inflating: activations/img19/fc6/input.csv
#   inflating: activations/img19/fc6/output.csv
#   inflating: activations/img19/output/input.csv
#   inflating: activations/img19/output/output.csv
#   inflating: activations/img20/input.csv
#   inflating: activations/img20/output.csv
#   inflating: activations/img20/conv1/input.csv
#   inflating: activations/img20/conv1/output.csv
#   inflating: activations/img20/maxpool2/input.csv
#   inflating: activations/img20/maxpool2/output.csv
#   inflating: activations/img20/conv3/input.csv
#   inflating: activations/img20/conv3/output.csv
#   inflating: activations/img20/maxpool4/input.csv
#   inflating: activations/img20/maxpool4/output.csv
#   inflating: activations/img20/conv5/input.csv
#   inflating: activations/img20/conv5/output.csv
#   inflating: activations/img20/fc6/input.csv
#   inflating: activations/img20/fc6/output.csv
#   inflating: activations/img20/output/input.csv
#   inflating: activations/img20/output/output.csv
#   inflating: activations/img21/input.csv
#   inflating: activations/img21/output.csv
#   inflating: activations/img21/conv1/input.csv
#   inflating: activations/img21/conv1/output.csv
#   inflating: activations/img21/maxpool2/input.csv
#   inflating: activations/img21/maxpool2/output.csv
#   inflating: activations/img21/conv3/input.csv
#   inflating: activations/img21/conv3/output.csv
#   inflating: activations/img21/maxpool4/input.csv
#   inflating: activations/img21/maxpool4/output.csv
#   inflating: activations/img21/conv5/input.csv
#   inflating: activations/img21/conv5/output.csv
#   inflating: activations/img21/fc6/input.csv
#   inflating: activations/img21/fc6/output.csv
#   inflating: activations/img21/output/input.csv
#   inflating: activations/img21/output/output.csv
#   inflating: activations/img22/input.csv
#   inflating: activations/img22/output.csv
#   inflating: activations/img22/conv1/input.csv
#   inflating: activations/img22/conv1/output.csv
#   inflating: activations/img22/maxpool2/input.csv
#   inflating: activations/img22/maxpool2/output.csv
#   inflating: activations/img22/conv3/input.csv
#   inflating: activations/img22/conv3/output.csv
#   inflating: activations/img22/maxpool4/input.csv
#   inflating: activations/img22/maxpool4/output.csv
#   inflating: activations/img22/conv5/input.csv
#   inflating: activations/img22/conv5/output.csv
#   inflating: activations/img22/fc6/input.csv
#   inflating: activations/img22/fc6/output.csv
#   inflating: activations/img22/output/input.csv
#   inflating: activations/img22/output/output.csv
#   inflating: activations/img23/input.csv
#   inflating: activations/img23/output.csv
#   inflating: activations/img23/conv1/input.csv
#   inflating: activations/img23/conv1/output.csv
#   inflating: activations/img23/maxpool2/input.csv
#   inflating: activations/img23/maxpool2/output.csv
#   inflating: activations/img23/conv3/input.csv
#   inflating: activations/img23/conv3/output.csv
#   inflating: activations/img23/maxpool4/input.csv
#   inflating: activations/img23/maxpool4/output.csv
#   inflating: activations/img23/conv5/input.csv
#   inflating: activations/img23/conv5/output.csv
#   inflating: activations/img23/fc6/input.csv
#   inflating: activations/img23/fc6/output.csv
#   inflating: activations/img23/output/input.csv
#   inflating: activations/img23/output/output.csv
#   inflating: activations/img24/input.csv
#   inflating: activations/img24/output.csv
#   inflating: activations/img24/conv1/input.csv
#   inflating: activations/img24/conv1/output.csv
#   inflating: activations/img24/maxpool2/input.csv
#   inflating: activations/img24/maxpool2/output.csv
#   inflating: activations/img24/conv3/input.csv
#   inflating: activations/img24/conv3/output.csv
#   inflating: activations/img24/maxpool4/input.csv
#   inflating: activations/img24/maxpool4/output.csv
#   inflating: activations/img24/conv5/input.csv
#   inflating: activations/img24/conv5/output.csv
#   inflating: activations/img24/fc6/input.csv
#   inflating: activations/img24/fc6/output.csv
#   inflating: activations/img24/output/input.csv
#   inflating: activations/img24/output/output.csv
#   inflating: activations/img25/input.csv
#   inflating: activations/img25/output.csv
#   inflating: activations/img25/conv1/input.csv
#   inflating: activations/img25/conv1/output.csv
#   inflating: activations/img25/maxpool2/input.csv
#   inflating: activations/img25/maxpool2/output.csv
#   inflating: activations/img25/conv3/input.csv
#   inflating: activations/img25/conv3/output.csv
#   inflating: activations/img25/maxpool4/input.csv
#   inflating: activations/img25/maxpool4/output.csv
#   inflating: activations/img25/conv5/input.csv
#   inflating: activations/img25/conv5/output.csv
#   inflating: activations/img25/fc6/input.csv
#   inflating: activations/img25/fc6/output.csv
#   inflating: activations/img25/output/input.csv
#   inflating: activations/img25/output/output.csv
#   inflating: activations/img26/input.csv
#   inflating: activations/img26/output.csv
#   inflating: activations/img26/conv1/input.csv
#   inflating: activations/img26/conv1/output.csv
#   inflating: activations/img26/maxpool2/input.csv
#   inflating: activations/img26/maxpool2/output.csv
#   inflating: activations/img26/conv3/input.csv
#   inflating: activations/img26/conv3/output.csv
#   inflating: activations/img26/maxpool4/input.csv
#   inflating: activations/img26/maxpool4/output.csv
#   inflating: activations/img26/conv5/input.csv
#   inflating: activations/img26/conv5/output.csv
#   inflating: activations/img26/fc6/input.csv
#   inflating: activations/img26/fc6/output.csv
#   inflating: activations/img26/output/input.csv
#   inflating: activations/img26/output/output.csv
#   inflating: activations/img27/input.csv
#   inflating: activations/img27/output.csv
#   inflating: activations/img27/conv1/input.csv
#   inflating: activations/img27/conv1/output.csv
#   inflating: activations/img27/maxpool2/input.csv
#   inflating: activations/img27/maxpool2/output.csv
#   inflating: activations/img27/conv3/input.csv
#   inflating: activations/img27/conv3/output.csv
#   inflating: activations/img27/maxpool4/input.csv
#   inflating: activations/img27/maxpool4/output.csv
#   inflating: activations/img27/conv5/input.csv
#   inflating: activations/img27/conv5/output.csv
#   inflating: activations/img27/fc6/input.csv
#   inflating: activations/img27/fc6/output.csv
#   inflating: activations/img27/output/input.csv
#   inflating: activations/img27/output/output.csv
#   inflating: activations/img28/input.csv
#   inflating: activations/img28/output.csv
#   inflating: activations/img28/conv1/input.csv
#   inflating: activations/img28/conv1/output.csv
#   inflating: activations/img28/maxpool2/input.csv
#   inflating: activations/img28/maxpool2/output.csv
#   inflating: activations/img28/conv3/input.csv
#   inflating: activations/img28/conv3/output.csv
#   inflating: activations/img28/maxpool4/input.csv
#   inflating: activations/img28/maxpool4/output.csv
#   inflating: activations/img28/conv5/input.csv
#   inflating: activations/img28/conv5/output.csv
#   inflating: activations/img28/fc6/input.csv
#   inflating: activations/img28/fc6/output.csv
#   inflating: activations/img28/output/input.csv
#   inflating: activations/img28/output/output.csv
#   inflating: activations/img29/input.csv
#   inflating: activations/img29/output.csv
#   inflating: activations/img29/conv1/input.csv
#   inflating: activations/img29/conv1/output.csv
#   inflating: activations/img29/maxpool2/input.csv
#   inflating: activations/img29/maxpool2/output.csv
#   inflating: activations/img29/conv3/input.csv
#   inflating: activations/img29/conv3/output.csv
#   inflating: activations/img29/maxpool4/input.csv
#   inflating: activations/img29/maxpool4/output.csv
#   inflating: activations/img29/conv5/input.csv
#   inflating: activations/img29/conv5/output.csv
#   inflating: activations/img29/fc6/input.csv
#   inflating: activations/img29/fc6/output.csv
#   inflating: activations/img29/output/input.csv
#   inflating: activations/img29/output/output.csv
#   inflating: activations/img30/input.csv
#   inflating: activations/img30/output.csv
#   inflating: activations/img30/conv1/input.csv
#   inflating: activations/img30/conv1/output.csv
#   inflating: activations/img30/maxpool2/input.csv
#   inflating: activations/img30/maxpool2/output.csv
#   inflating: activations/img30/conv3/input.csv
#   inflating: activations/img30/conv3/output.csv
#   inflating: activations/img30/maxpool4/input.csv
#   inflating: activations/img30/maxpool4/output.csv
#   inflating: activations/img30/conv5/input.csv
#   inflating: activations/img30/conv5/output.csv
#   inflating: activations/img30/fc6/input.csv
#   inflating: activations/img30/fc6/output.csv
#   inflating: activations/img30/output/input.csv
#   inflating: activations/img30/output/output.csv
#   inflating: activations/img31/input.csv
#   inflating: activations/img31/output.csv
#   inflating: activations/img31/conv1/input.csv
#   inflating: activations/img31/conv1/output.csv
#   inflating: activations/img31/maxpool2/input.csv
#   inflating: activations/img31/maxpool2/output.csv
#   inflating: activations/img31/conv3/input.csv
#   inflating: activations/img31/conv3/output.csv
#   inflating: activations/img31/maxpool4/input.csv
#   inflating: activations/img31/maxpool4/output.csv
#   inflating: activations/img31/conv5/input.csv
#   inflating: activations/img31/conv5/output.csv
#   inflating: activations/img31/fc6/input.csv
#   inflating: activations/img31/fc6/output.csv
#   inflating: activations/img31/output/input.csv
#   inflating: activations/img31/output/output.csv
#   inflating: activations/img32/input.csv
#   inflating: activations/img32/output.csv
#   inflating: activations/img32/conv1/input.csv
#   inflating: activations/img32/conv1/output.csv
#   inflating: activations/img32/maxpool2/input.csv
#   inflating: activations/img32/maxpool2/output.csv
#   inflating: activations/img32/conv3/input.csv
#   inflating: activations/img32/conv3/output.csv
#   inflating: activations/img32/maxpool4/input.csv
#   inflating: activations/img32/maxpool4/output.csv
#   inflating: activations/img32/conv5/input.csv
#   inflating: activations/img32/conv5/output.csv
#   inflating: activations/img32/fc6/input.csv
#   inflating: activations/img32/fc6/output.csv
#   inflating: activations/img32/output/input.csv
#   inflating: activations/img32/output/output.csv
#   inflating: activations/img33/input.csv
#   inflating: activations/img33/output.csv
#   inflating: activations/img33/conv1/input.csv
#   inflating: activations/img33/conv1/output.csv
#   inflating: activations/img33/maxpool2/input.csv
#   inflating: activations/img33/maxpool2/output.csv
#   inflating: activations/img33/conv3/input.csv
#   inflating: activations/img33/conv3/output.csv
#   inflating: activations/img33/maxpool4/input.csv
#   inflating: activations/img33/maxpool4/output.csv
#   inflating: activations/img33/conv5/input.csv
#   inflating: activations/img33/conv5/output.csv
#   inflating: activations/img33/fc6/input.csv
#   inflating: activations/img33/fc6/output.csv
#   inflating: activations/img33/output/input.csv
#   inflating: activations/img33/output/output.csv
#   inflating: activations/img34/input.csv
#   inflating: activations/img34/output.csv
#   inflating: activations/img34/conv1/input.csv
#   inflating: activations/img34/conv1/output.csv
#   inflating: activations/img34/maxpool2/input.csv
#   inflating: activations/img34/maxpool2/output.csv
#   inflating: activations/img34/conv3/input.csv
#   inflating: activations/img34/conv3/output.csv
#   inflating: activations/img34/maxpool4/input.csv
#   inflating: activations/img34/maxpool4/output.csv
#   inflating: activations/img34/conv5/input.csv
#   inflating: activations/img34/conv5/output.csv
#   inflating: activations/img34/fc6/input.csv
#   inflating: activations/img34/fc6/output.csv
#   inflating: activations/img34/output/input.csv
#   inflating: activations/img34/output/output.csv
#   inflating: activations/img35/input.csv
#   inflating: activations/img35/output.csv
#   inflating: activations/img35/conv1/input.csv
#   inflating: activations/img35/conv1/output.csv
#   inflating: activations/img35/maxpool2/input.csv
#   inflating: activations/img35/maxpool2/output.csv
#   inflating: activations/img35/conv3/input.csv
#   inflating: activations/img35/conv3/output.csv
#   inflating: activations/img35/maxpool4/input.csv
#   inflating: activations/img35/maxpool4/output.csv
#   inflating: activations/img35/conv5/input.csv
#   inflating: activations/img35/conv5/output.csv
#   inflating: activations/img35/fc6/input.csv
#   inflating: activations/img35/fc6/output.csv
#   inflating: activations/img35/output/input.csv
#   inflating: activations/img35/output/output.csv
#   inflating: activations/img36/input.csv
#   inflating: activations/img36/output.csv
#   inflating: activations/img36/conv1/input.csv
#   inflating: activations/img36/conv1/output.csv
#   inflating: activations/img36/maxpool2/input.csv
#   inflating: activations/img36/maxpool2/output.csv
#   inflating: activations/img36/conv3/input.csv
#   inflating: activations/img36/conv3/output.csv
#   inflating: activations/img36/maxpool4/input.csv
#   inflating: activations/img36/maxpool4/output.csv
#   inflating: activations/img36/conv5/input.csv
#   inflating: activations/img36/conv5/output.csv
#   inflating: activations/img36/fc6/input.csv
#   inflating: activations/img36/fc6/output.csv
#   inflating: activations/img36/output/input.csv
#   inflating: activations/img36/output/output.csv
#   inflating: activations/img37/input.csv
#   inflating: activations/img37/output.csv
#   inflating: activations/img37/conv1/input.csv
#   inflating: activations/img37/conv1/output.csv
#   inflating: activations/img37/maxpool2/input.csv
#   inflating: activations/img37/maxpool2/output.csv
#   inflating: activations/img37/conv3/input.csv
#   inflating: activations/img37/conv3/output.csv
#   inflating: activations/img37/maxpool4/input.csv
#   inflating: activations/img37/maxpool4/output.csv
#   inflating: activations/img37/conv5/input.csv
#   inflating: activations/img37/conv5/output.csv
#   inflating: activations/img37/fc6/input.csv
#   inflating: activations/img37/fc6/output.csv
#   inflating: activations/img37/output/input.csv
#   inflating: activations/img37/output/output.csv
#   inflating: activations/img38/input.csv
#   inflating: activations/img38/output.csv
#   inflating: activations/img38/conv1/input.csv
#   inflating: activations/img38/conv1/output.csv
#   inflating: activations/img38/maxpool2/input.csv
#   inflating: activations/img38/maxpool2/output.csv
#   inflating: activations/img38/conv3/input.csv
#   inflating: activations/img38/conv3/output.csv
#   inflating: activations/img38/maxpool4/input.csv
#   inflating: activations/img38/maxpool4/output.csv
#   inflating: activations/img38/conv5/input.csv
#   inflating: activations/img38/conv5/output.csv
#   inflating: activations/img38/fc6/input.csv
#   inflating: activations/img38/fc6/output.csv
#   inflating: activations/img38/output/input.csv
#   inflating: activations/img38/output/output.csv
#   inflating: activations/img39/input.csv
#   inflating: activations/img39/output.csv
#   inflating: activations/img39/conv1/input.csv
#   inflating: activations/img39/conv1/output.csv
#   inflating: activations/img39/maxpool2/input.csv
#   inflating: activations/img39/maxpool2/output.csv
#   inflating: activations/img39/conv3/input.csv
#   inflating: activations/img39/conv3/output.csv
#   inflating: activations/img39/maxpool4/input.csv
#   inflating: activations/img39/maxpool4/output.csv
#   inflating: activations/img39/conv5/input.csv
#   inflating: activations/img39/conv5/output.csv
#   inflating: activations/img39/fc6/input.csv
#   inflating: activations/img39/fc6/output.csv
#   inflating: activations/img39/output/input.csv
#   inflating: activations/img39/output/output.csv
#   inflating: activations/img40/input.csv
#   inflating: activations/img40/output.csv
#   inflating: activations/img40/conv1/input.csv
#   inflating: activations/img40/conv1/output.csv
#   inflating: activations/img40/maxpool2/input.csv
#   inflating: activations/img40/maxpool2/output.csv
#   inflating: activations/img40/conv3/input.csv
#   inflating: activations/img40/conv3/output.csv
#   inflating: activations/img40/maxpool4/input.csv
#   inflating: activations/img40/maxpool4/output.csv
#   inflating: activations/img40/conv5/input.csv
#   inflating: activations/img40/conv5/output.csv
#   inflating: activations/img40/fc6/input.csv
#   inflating: activations/img40/fc6/output.csv
#   inflating: activations/img40/output/input.csv
#   inflating: activations/img40/output/output.csv
#   inflating: activations/img41/input.csv
#   inflating: activations/img41/output.csv
#   inflating: activations/img41/conv1/input.csv
#   inflating: activations/img41/conv1/output.csv
#   inflating: activations/img41/maxpool2/input.csv
#   inflating: activations/img41/maxpool2/output.csv
#   inflating: activations/img41/conv3/input.csv
#   inflating: activations/img41/conv3/output.csv
#   inflating: activations/img41/maxpool4/input.csv
#   inflating: activations/img41/maxpool4/output.csv
#   inflating: activations/img41/conv5/input.csv
#   inflating: activations/img41/conv5/output.csv
#   inflating: activations/img41/fc6/input.csv
#   inflating: activations/img41/fc6/output.csv
#   inflating: activations/img41/output/input.csv
#   inflating: activations/img41/output/output.csv
#   inflating: activations/img42/input.csv
#   inflating: activations/img42/output.csv
#   inflating: activations/img42/conv1/input.csv
#   inflating: activations/img42/conv1/output.csv
#   inflating: activations/img42/maxpool2/input.csv
#   inflating: activations/img42/maxpool2/output.csv
#   inflating: activations/img42/conv3/input.csv
#   inflating: activations/img42/conv3/output.csv
#   inflating: activations/img42/maxpool4/input.csv
#   inflating: activations/img42/maxpool4/output.csv
#   inflating: activations/img42/conv5/input.csv
#   inflating: activations/img42/conv5/output.csv
#   inflating: activations/img42/fc6/input.csv
#   inflating: activations/img42/fc6/output.csv
#   inflating: activations/img42/output/input.csv
#   inflating: activations/img42/output/output.csv
#   inflating: activations/img43/input.csv
#   inflating: activations/img43/output.csv
#   inflating: activations/img43/conv1/input.csv
#   inflating: activations/img43/conv1/output.csv
#   inflating: activations/img43/maxpool2/input.csv
#   inflating: activations/img43/maxpool2/output.csv
#   inflating: activations/img43/conv3/input.csv
#   inflating: activations/img43/conv3/output.csv
#   inflating: activations/img43/maxpool4/input.csv
#   inflating: activations/img43/maxpool4/output.csv
#   inflating: activations/img43/conv5/input.csv
#   inflating: activations/img43/conv5/output.csv
#   inflating: activations/img43/fc6/input.csv
#   inflating: activations/img43/fc6/output.csv
#   inflating: activations/img43/output/input.csv
#   inflating: activations/img43/output/output.csv
#   inflating: activations/img44/input.csv
#   inflating: activations/img44/output.csv
#   inflating: activations/img44/conv1/input.csv
#   inflating: activations/img44/conv1/output.csv
#   inflating: activations/img44/maxpool2/input.csv
#   inflating: activations/img44/maxpool2/output.csv
#   inflating: activations/img44/conv3/input.csv
#   inflating: activations/img44/conv3/output.csv
#   inflating: activations/img44/maxpool4/input.csv
#   inflating: activations/img44/maxpool4/output.csv
#   inflating: activations/img44/conv5/input.csv
#   inflating: activations/img44/conv5/output.csv
#   inflating: activations/img44/fc6/input.csv
#   inflating: activations/img44/fc6/output.csv
#   inflating: activations/img44/output/input.csv
#   inflating: activations/img44/output/output.csv
#   inflating: activations/img45/input.csv
#   inflating: activations/img45/output.csv
#   inflating: activations/img45/conv1/input.csv
#   inflating: activations/img45/conv1/output.csv
#   inflating: activations/img45/maxpool2/input.csv
#   inflating: activations/img45/maxpool2/output.csv
#   inflating: activations/img45/conv3/input.csv
#   inflating: activations/img45/conv3/output.csv
#   inflating: activations/img45/maxpool4/input.csv
#   inflating: activations/img45/maxpool4/output.csv
#   inflating: activations/img45/conv5/input.csv
#   inflating: activations/img45/conv5/output.csv
#   inflating: activations/img45/fc6/input.csv
#   inflating: activations/img45/fc6/output.csv
#   inflating: activations/img45/output/input.csv
#   inflating: activations/img45/output/output.csv
#   inflating: activations/img46/input.csv
#   inflating: activations/img46/output.csv
#   inflating: activations/img46/conv1/input.csv
#   inflating: activations/img46/conv1/output.csv
#   inflating: activations/img46/maxpool2/input.csv
#   inflating: activations/img46/maxpool2/output.csv
#   inflating: activations/img46/conv3/input.csv
#   inflating: activations/img46/conv3/output.csv
#   inflating: activations/img46/maxpool4/input.csv
#   inflating: activations/img46/maxpool4/output.csv
#   inflating: activations/img46/conv5/input.csv
#   inflating: activations/img46/conv5/output.csv
#   inflating: activations/img46/fc6/input.csv
#   inflating: activations/img46/fc6/output.csv
#   inflating: activations/img46/output/input.csv
#   inflating: activations/img46/output/output.csv
#   inflating: activations/img47/input.csv
#   inflating: activations/img47/output.csv
#   inflating: activations/img47/conv1/input.csv
#   inflating: activations/img47/conv1/output.csv
#   inflating: activations/img47/maxpool2/input.csv
#   inflating: activations/img47/maxpool2/output.csv
#   inflating: activations/img47/conv3/input.csv
#   inflating: activations/img47/conv3/output.csv
#   inflating: activations/img47/maxpool4/input.csv
#   inflating: activations/img47/maxpool4/output.csv
#   inflating: activations/img47/conv5/input.csv
#   inflating: activations/img47/conv5/output.csv
#   inflating: activations/img47/fc6/input.csv
#   inflating: activations/img47/fc6/output.csv
#   inflating: activations/img47/output/input.csv
#   inflating: activations/img47/output/output.csv
#   inflating: activations/img48/input.csv
#   inflating: activations/img48/output.csv
#   inflating: activations/img48/conv1/input.csv
#   inflating: activations/img48/conv1/output.csv
#   inflating: activations/img48/maxpool2/input.csv
#   inflating: activations/img48/maxpool2/output.csv
#   inflating: activations/img48/conv3/input.csv
#   inflating: activations/img48/conv3/output.csv
#   inflating: activations/img48/maxpool4/input.csv
#   inflating: activations/img48/maxpool4/output.csv
#   inflating: activations/img48/conv5/input.csv
#   inflating: activations/img48/conv5/output.csv
#   inflating: activations/img48/fc6/input.csv
#   inflating: activations/img48/fc6/output.csv
#   inflating: activations/img48/output/input.csv
#   inflating: activations/img48/output/output.csv
#   inflating: activations/img49/input.csv
#   inflating: activations/img49/output.csv
#   inflating: activations/img49/conv1/input.csv
#   inflating: activations/img49/conv1/output.csv
#   inflating: activations/img49/maxpool2/input.csv
#   inflating: activations/img49/maxpool2/output.csv
#   inflating: activations/img49/conv3/input.csv
#   inflating: activations/img49/conv3/output.csv
#   inflating: activations/img49/maxpool4/input.csv
#   inflating: activations/img49/maxpool4/output.csv
#   inflating: activations/img49/conv5/input.csv
#   inflating: activations/img49/conv5/output.csv
#   inflating: activations/img49/fc6/input.csv
#   inflating: activations/img49/fc6/output.csv
#   inflating: activations/img49/output/input.csv
#   inflating: activations/img49/output/output.csv
#   inflating: activations/img50/input.csv
#   inflating: activations/img50/output.csv
#   inflating: activations/img50/conv1/input.csv
#   inflating: activations/img50/conv1/output.csv
#   inflating: activations/img50/maxpool2/input.csv
#   inflating: activations/img50/maxpool2/output.csv
#   inflating: activations/img50/conv3/input.csv
#   inflating: activations/img50/conv3/output.csv
#   inflating: activations/img50/maxpool4/input.csv
#   inflating: activations/img50/maxpool4/output.csv
#   inflating: activations/img50/conv5/input.csv
#   inflating: activations/img50/conv5/output.csv
#   inflating: activations/img50/fc6/input.csv
#   inflating: activations/img50/fc6/output.csv
#   inflating: activations/img50/output/input.csv
#   inflating: activations/img50/output/output.csv
#   inflating: activations/img51/input.csv
#   inflating: activations/img51/output.csv
#   inflating: activations/img51/conv1/input.csv
#   inflating: activations/img51/conv1/output.csv
#   inflating: activations/img51/maxpool2/input.csv
#   inflating: activations/img51/maxpool2/output.csv
#   inflating: activations/img51/conv3/input.csv
#   inflating: activations/img51/conv3/output.csv
#   inflating: activations/img51/maxpool4/input.csv
#   inflating: activations/img51/maxpool4/output.csv
#   inflating: activations/img51/conv5/input.csv
#   inflating: activations/img51/conv5/output.csv
#   inflating: activations/img51/fc6/input.csv
#   inflating: activations/img51/fc6/output.csv
#   inflating: activations/img51/output/input.csv
#   inflating: activations/img51/output/output.csv
#   inflating: activations/img52/input.csv
#   inflating: activations/img52/output.csv
#   inflating: activations/img52/conv1/input.csv
#   inflating: activations/img52/conv1/output.csv
#   inflating: activations/img52/maxpool2/input.csv
#   inflating: activations/img52/maxpool2/output.csv
#   inflating: activations/img52/conv3/input.csv
#   inflating: activations/img52/conv3/output.csv
#   inflating: activations/img52/maxpool4/input.csv
#   inflating: activations/img52/maxpool4/output.csv
#   inflating: activations/img52/conv5/input.csv
#   inflating: activations/img52/conv5/output.csv
#   inflating: activations/img52/fc6/input.csv
#   inflating: activations/img52/fc6/output.csv
#   inflating: activations/img52/output/input.csv
#   inflating: activations/img52/output/output.csv
#   inflating: activations/img53/input.csv
#   inflating: activations/img53/output.csv
#   inflating: activations/img53/conv1/input.csv
#   inflating: activations/img53/conv1/output.csv
#   inflating: activations/img53/maxpool2/input.csv
#   inflating: activations/img53/maxpool2/output.csv
#   inflating: activations/img53/conv3/input.csv
#   inflating: activations/img53/conv3/output.csv
#   inflating: activations/img53/maxpool4/input.csv
#   inflating: activations/img53/maxpool4/output.csv
#   inflating: activations/img53/conv5/input.csv
#   inflating: activations/img53/conv5/output.csv
#   inflating: activations/img53/fc6/input.csv
#   inflating: activations/img53/fc6/output.csv
#   inflating: activations/img53/output/input.csv
#   inflating: activations/img53/output/output.csv
#   inflating: activations/img54/input.csv
#   inflating: activations/img54/output.csv
#   inflating: activations/img54/conv1/input.csv
#   inflating: activations/img54/conv1/output.csv
#   inflating: activations/img54/maxpool2/input.csv
#   inflating: activations/img54/maxpool2/output.csv
#   inflating: activations/img54/conv3/input.csv
#   inflating: activations/img54/conv3/output.csv
#   inflating: activations/img54/maxpool4/input.csv
#   inflating: activations/img54/maxpool4/output.csv
#   inflating: activations/img54/conv5/input.csv
#   inflating: activations/img54/conv5/output.csv
#   inflating: activations/img54/fc6/input.csv
#   inflating: activations/img54/fc6/output.csv
#   inflating: activations/img54/output/input.csv
#   inflating: activations/img54/output/output.csv
#   inflating: activations/img55/input.csv
#   inflating: activations/img55/output.csv
#   inflating: activations/img55/conv1/input.csv
#   inflating: activations/img55/conv1/output.csv
#   inflating: activations/img55/maxpool2/input.csv
#   inflating: activations/img55/maxpool2/output.csv
#   inflating: activations/img55/conv3/input.csv
#   inflating: activations/img55/conv3/output.csv
#   inflating: activations/img55/maxpool4/input.csv
#   inflating: activations/img55/maxpool4/output.csv
#   inflating: activations/img55/conv5/input.csv
#   inflating: activations/img55/conv5/output.csv
#   inflating: activations/img55/fc6/input.csv
#   inflating: activations/img55/fc6/output.csv
#   inflating: activations/img55/output/input.csv
#   inflating: activations/img55/output/output.csv
#   inflating: activations/img56/input.csv
#   inflating: activations/img56/output.csv
#   inflating: activations/img56/conv1/input.csv
#   inflating: activations/img56/conv1/output.csv
#   inflating: activations/img56/maxpool2/input.csv
#   inflating: activations/img56/maxpool2/output.csv
#   inflating: activations/img56/conv3/input.csv
#   inflating: activations/img56/conv3/output.csv
#   inflating: activations/img56/maxpool4/input.csv
#   inflating: activations/img56/maxpool4/output.csv
#   inflating: activations/img56/conv5/input.csv
#   inflating: activations/img56/conv5/output.csv
#   inflating: activations/img56/fc6/input.csv
#   inflating: activations/img56/fc6/output.csv
#   inflating: activations/img56/output/input.csv
#   inflating: activations/img56/output/output.csv
#   inflating: activations/img57/input.csv
#   inflating: activations/img57/output.csv
#   inflating: activations/img57/conv1/input.csv
#   inflating: activations/img57/conv1/output.csv
#   inflating: activations/img57/maxpool2/input.csv
#   inflating: activations/img57/maxpool2/output.csv
#   inflating: activations/img57/conv3/input.csv
#   inflating: activations/img57/conv3/output.csv
#   inflating: activations/img57/maxpool4/input.csv
#   inflating: activations/img57/maxpool4/output.csv
#   inflating: activations/img57/conv5/input.csv
#   inflating: activations/img57/conv5/output.csv
#   inflating: activations/img57/fc6/input.csv
#   inflating: activations/img57/fc6/output.csv
#   inflating: activations/img57/output/input.csv
#   inflating: activations/img57/output/output.csv
#   inflating: activations/img58/input.csv
#   inflating: activations/img58/output.csv
#   inflating: activations/img58/conv1/input.csv
#   inflating: activations/img58/conv1/output.csv
#   inflating: activations/img58/maxpool2/input.csv
#   inflating: activations/img58/maxpool2/output.csv
#   inflating: activations/img58/conv3/input.csv
#   inflating: activations/img58/conv3/output.csv
#   inflating: activations/img58/maxpool4/input.csv
#   inflating: activations/img58/maxpool4/output.csv
#   inflating: activations/img58/conv5/input.csv
#   inflating: activations/img58/conv5/output.csv
#   inflating: activations/img58/fc6/input.csv
#   inflating: activations/img58/fc6/output.csv
#   inflating: activations/img58/output/input.csv
#   inflating: activations/img58/output/output.csv
#   inflating: activations/img59/input.csv
#   inflating: activations/img59/output.csv
#   inflating: activations/img59/conv1/input.csv
#   inflating: activations/img59/conv1/output.csv
#   inflating: activations/img59/maxpool2/input.csv
#   inflating: activations/img59/maxpool2/output.csv
#   inflating: activations/img59/conv3/input.csv
#   inflating: activations/img59/conv3/output.csv
#   inflating: activations/img59/maxpool4/input.csv
#   inflating: activations/img59/maxpool4/output.csv
#   inflating: activations/img59/conv5/input.csv
#   inflating: activations/img59/conv5/output.csv
#   inflating: activations/img59/fc6/input.csv
#   inflating: activations/img59/fc6/output.csv
#   inflating: activations/img59/output/input.csv
#   inflating: activations/img59/output/output.csv
#   inflating: activations/img60/input.csv
#   inflating: activations/img60/output.csv
#   inflating: activations/img60/conv1/input.csv
#   inflating: activations/img60/conv1/output.csv
#   inflating: activations/img60/maxpool2/input.csv
#   inflating: activations/img60/maxpool2/output.csv
#   inflating: activations/img60/conv3/input.csv
#   inflating: activations/img60/conv3/output.csv
# ...
#   inflating: activations/img79/fc6/input.csv
#   inflating: activations/img79/fc6/output.csv
#   inflating: activations/img79/output/input.csv
#   inflating: activations/img79/output/output.csv
#   inflating: activations/img80/input.csv
#   inflating: activations/img80/output.csv
#   inflating: activations/img80/conv1/input.csv
#   inflating: activations/img80/conv1/output.csv
#   inflating: activations/img80/maxpool2/input.csv
#   inflating: activations/img80/maxpool2/output.csv
#   inflating: activations/img80/conv3/input.csv
#   inflating: activations/img80/conv3/output.csv
#   inflating: activations/img80/maxpool4/input.csv
#   inflating: activations/img80/maxpool4/output.csv
#   inflating: activations/img80/conv5/input.csv
#   inflating: activations/img80/conv5/output.csv
#   inflating: activations/img80/fc6/input.csv
#   inflating: activations/img80/fc6/output.csv
#   inflating: activations/img80/output/input.csv
#   inflating: activations/img80/output/output.csv
#   inflating: activations/img81/input.csv
#   inflating: activations/img81/output.csv
#   inflating: activations/img81/conv1/input.csv
#   inflating: activations/img81/conv1/output.csv
#   inflating: activations/img81/maxpool2/input.csv
#   inflating: activations/img81/maxpool2/output.csv
#   inflating: activations/img81/conv3/input.csv
#   inflating: activations/img81/conv3/output.csv
#   inflating: activations/img81/maxpool4/input.csv
#   inflating: activations/img81/maxpool4/output.csv
#   inflating: activations/img81/conv5/input.csv
#   inflating: activations/img81/conv5/output.csv
#   inflating: activations/img81/fc6/input.csv
#   inflating: activations/img81/fc6/output.csv
#   inflating: activations/img81/output/input.csv
#   inflating: activations/img81/output/output.csv
#   inflating: activations/img82/input.csv
#   inflating: activations/img82/output.csv
#   inflating: activations/img82/conv1/input.csv
#   inflating: activations/img82/conv1/output.csv
#   inflating: activations/img82/maxpool2/input.csv
#   inflating: activations/img82/maxpool2/output.csv
#   inflating: activations/img82/conv3/input.csv
#   inflating: activations/img82/conv3/output.csv
#   inflating: activations/img82/maxpool4/input.csv
#   inflating: activations/img82/maxpool4/output.csv
#   inflating: activations/img82/conv5/input.csv
#   inflating: activations/img82/conv5/output.csv
#   inflating: activations/img82/fc6/input.csv
#   inflating: activations/img82/fc6/output.csv
#   inflating: activations/img82/output/input.csv
#   inflating: activations/img82/output/output.csv
#   inflating: activations/img83/input.csv
#   inflating: activations/img83/output.csv
#   inflating: activations/img83/conv1/input.csv
#   inflating: activations/img83/conv1/output.csv
#   inflating: activations/img83/maxpool2/input.csv
#   inflating: activations/img83/maxpool2/output.csv
#   inflating: activations/img83/conv3/input.csv
#   inflating: activations/img83/conv3/output.csv
#   inflating: activations/img83/maxpool4/input.csv
#   inflating: activations/img83/maxpool4/output.csv
#   inflating: activations/img83/conv5/input.csv
#   inflating: activations/img83/conv5/output.csv
#   inflating: activations/img83/fc6/input.csv
#   inflating: activations/img83/fc6/output.csv
#   inflating: activations/img83/output/input.csv
#   inflating: activations/img83/output/output.csv
#   inflating: activations/img84/input.csv
#   inflating: activations/img84/output.csv
#   inflating: activations/img84/conv1/input.csv
#   inflating: activations/img84/conv1/output.csv
#   inflating: activations/img84/maxpool2/input.csv
#   inflating: activations/img84/maxpool2/output.csv
#   inflating: activations/img84/conv3/input.csv
#   inflating: activations/img84/conv3/output.csv
#   inflating: activations/img84/maxpool4/input.csv
#   inflating: activations/img84/maxpool4/output.csv
#   inflating: activations/img84/conv5/input.csv
#   inflating: activations/img84/conv5/output.csv
#   inflating: activations/img84/fc6/input.csv
#   inflating: activations/img84/fc6/output.csv
#   inflating: activations/img84/output/input.csv
#   inflating: activations/img84/output/output.csv
#   inflating: activations/img85/input.csv
#   inflating: activations/img85/output.csv
#   inflating: activations/img85/conv1/input.csv
#   inflating: activations/img85/conv1/output.csv
#   inflating: activations/img85/maxpool2/input.csv
#   inflating: activations/img85/maxpool2/output.csv
#   inflating: activations/img85/conv3/input.csv
#   inflating: activations/img85/conv3/output.csv
#   inflating: activations/img85/maxpool4/input.csv
#   inflating: activations/img85/maxpool4/output.csv
#   inflating: activations/img85/conv5/input.csv
#   inflating: activations/img85/conv5/output.csv
#   inflating: activations/img85/fc6/input.csv
#   inflating: activations/img85/fc6/output.csv
#   inflating: activations/img85/output/input.csv
#   inflating: activations/img85/output/output.csv
#   inflating: activations/img86/input.csv
#   inflating: activations/img86/output.csv
#   inflating: activations/img86/conv1/input.csv
#   inflating: activations/img86/conv1/output.csv
#   inflating: activations/img86/maxpool2/input.csv
#   inflating: activations/img86/maxpool2/output.csv
#   inflating: activations/img86/conv3/input.csv
#   inflating: activations/img86/conv3/output.csv
#   inflating: activations/img86/maxpool4/input.csv
#   inflating: activations/img86/maxpool4/output.csv
#   inflating: activations/img86/conv5/input.csv
#   inflating: activations/img86/conv5/output.csv
#   inflating: activations/img86/fc6/input.csv
#   inflating: activations/img86/fc6/output.csv
#   inflating: activations/img86/output/input.csv
#   inflating: activations/img86/output/output.csv
#   inflating: activations/img87/input.csv
#   inflating: activations/img87/output.csv
#   inflating: activations/img87/conv1/input.csv
#   inflating: activations/img87/conv1/output.csv
#   inflating: activations/img87/maxpool2/input.csv
#   inflating: activations/img87/maxpool2/output.csv
#   inflating: activations/img87/conv3/input.csv
#   inflating: activations/img87/conv3/output.csv
#   inflating: activations/img87/maxpool4/input.csv
#   inflating: activations/img87/maxpool4/output.csv
#   inflating: activations/img87/conv5/input.csv
#   inflating: activations/img87/conv5/output.csv
#   inflating: activations/img87/fc6/input.csv
#   inflating: activations/img87/fc6/output.csv
#   inflating: activations/img87/output/input.csv
#   inflating: activations/img87/output/output.csv
#   inflating: activations/img88/input.csv
#   inflating: activations/img88/output.csv
#   inflating: activations/img88/conv1/input.csv
#   inflating: activations/img88/conv1/output.csv
#   inflating: activations/img88/maxpool2/input.csv
#   inflating: activations/img88/maxpool2/output.csv
#   inflating: activations/img88/conv3/input.csv
#   inflating: activations/img88/conv3/output.csv
#   inflating: activations/img88/maxpool4/input.csv
#   inflating: activations/img88/maxpool4/output.csv
#   inflating: activations/img88/conv5/input.csv
#   inflating: activations/img88/conv5/output.csv
#   inflating: activations/img88/fc6/input.csv
#   inflating: activations/img88/fc6/output.csv
#   inflating: activations/img88/output/input.csv
#   inflating: activations/img88/output/output.csv
#   inflating: activations/img89/input.csv
#   inflating: activations/img89/output.csv
#   inflating: activations/img89/conv1/input.csv
#   inflating: activations/img89/conv1/output.csv
#   inflating: activations/img89/maxpool2/input.csv
#   inflating: activations/img89/maxpool2/output.csv
#   inflating: activations/img89/conv3/input.csv
#   inflating: activations/img89/conv3/output.csv
#   inflating: activations/img89/maxpool4/input.csv
#   inflating: activations/img89/maxpool4/output.csv
#   inflating: activations/img89/conv5/input.csv
#   inflating: activations/img89/conv5/output.csv
#   inflating: activations/img89/fc6/input.csv
#   inflating: activations/img89/fc6/output.csv
#   inflating: activations/img89/output/input.csv
#   inflating: activations/img89/output/output.csv
#   inflating: activations/img90/input.csv
#   inflating: activations/img90/output.csv
#   inflating: activations/img90/conv1/input.csv
#   inflating: activations/img90/conv1/output.csv
#   inflating: activations/img90/maxpool2/input.csv
#   inflating: activations/img90/maxpool2/output.csv
#   inflating: activations/img90/conv3/input.csv
#   inflating: activations/img90/conv3/output.csv
#   inflating: activations/img90/maxpool4/input.csv
#   inflating: activations/img90/maxpool4/output.csv
#   inflating: activations/img90/conv5/input.csv
#   inflating: activations/img90/conv5/output.csv
#   inflating: activations/img90/fc6/input.csv
#   inflating: activations/img90/fc6/output.csv
#   inflating: activations/img90/output/input.csv
#   inflating: activations/img90/output/output.csv
#   inflating: activations/img91/input.csv
#   inflating: activations/img91/output.csv
#   inflating: activations/img91/conv1/input.csv
#   inflating: activations/img91/conv1/output.csv
#   inflating: activations/img91/maxpool2/input.csv
#   inflating: activations/img91/maxpool2/output.csv
#   inflating: activations/img91/conv3/input.csv
#   inflating: activations/img91/conv3/output.csv
#   inflating: activations/img91/maxpool4/input.csv
#   inflating: activations/img91/maxpool4/output.csv
#   inflating: activations/img91/conv5/input.csv
#   inflating: activations/img91/conv5/output.csv
#   inflating: activations/img91/fc6/input.csv
#   inflating: activations/img91/fc6/output.csv
#   inflating: activations/img91/output/input.csv
#   inflating: activations/img91/output/output.csv
#   inflating: activations/img92/input.csv
#   inflating: activations/img92/output.csv
#   inflating: activations/img92/conv1/input.csv
#   inflating: activations/img92/conv1/output.csv
#   inflating: activations/img92/maxpool2/input.csv
#   inflating: activations/img92/maxpool2/output.csv
#   inflating: activations/img92/conv3/input.csv
#   inflating: activations/img92/conv3/output.csv
#   inflating: activations/img92/maxpool4/input.csv
#   inflating: activations/img92/maxpool4/output.csv
#   inflating: activations/img92/conv5/input.csv
#   inflating: activations/img92/conv5/output.csv
#   inflating: activations/img92/fc6/input.csv
#   inflating: activations/img92/fc6/output.csv
#   inflating: activations/img92/output/input.csv
#   inflating: activations/img92/output/output.csv
#   inflating: activations/img93/input.csv
#   inflating: activations/img93/output.csv
#   inflating: activations/img93/conv1/input.csv
#   inflating: activations/img93/conv1/output.csv
#   inflating: activations/img93/maxpool2/input.csv
#   inflating: activations/img93/maxpool2/output.csv
#   inflating: activations/img93/conv3/input.csv
#   inflating: activations/img93/conv3/output.csv
#   inflating: activations/img93/maxpool4/input.csv
#   inflating: activations/img93/maxpool4/output.csv
#   inflating: activations/img93/conv5/input.csv
#   inflating: activations/img93/conv5/output.csv
#   inflating: activations/img93/fc6/input.csv
#   inflating: activations/img93/fc6/output.csv
#   inflating: activations/img93/output/input.csv
#   inflating: activations/img93/output/output.csv
#   inflating: activations/img94/input.csv
#   inflating: activations/img94/output.csv
#   inflating: activations/img94/conv1/input.csv
#   inflating: activations/img94/conv1/output.csv
#   inflating: activations/img94/maxpool2/input.csv
#   inflating: activations/img94/maxpool2/output.csv
#   inflating: activations/img94/conv3/input.csv
#   inflating: activations/img94/conv3/output.csv
#   inflating: activations/img94/maxpool4/input.csv
#   inflating: activations/img94/maxpool4/output.csv
#   inflating: activations/img94/conv5/input.csv
#   inflating: activations/img94/conv5/output.csv
#   inflating: activations/img94/fc6/input.csv
#   inflating: activations/img94/fc6/output.csv
#   inflating: activations/img94/output/input.csv
#   inflating: activations/img94/output/output.csv
#   inflating: activations/img95/input.csv
#   inflating: activations/img95/output.csv
#   inflating: activations/img95/conv1/input.csv
#   inflating: activations/img95/conv1/output.csv
#   inflating: activations/img95/maxpool2/input.csv
#   inflating: activations/img95/maxpool2/output.csv
#   inflating: activations/img95/conv3/input.csv
#   inflating: activations/img95/conv3/output.csv
#   inflating: activations/img95/maxpool4/input.csv
#   inflating: activations/img95/maxpool4/output.csv
#   inflating: activations/img95/conv5/input.csv
#   inflating: activations/img95/conv5/output.csv
#   inflating: activations/img95/fc6/input.csv
#   inflating: activations/img95/fc6/output.csv
#   inflating: activations/img95/output/input.csv
#   inflating: activations/img95/output/output.csv
#   inflating: activations/img96/input.csv
#   inflating: activations/img96/output.csv
#   inflating: activations/img96/conv1/input.csv
#   inflating: activations/img96/conv1/output.csv
#   inflating: activations/img96/maxpool2/input.csv
#   inflating: activations/img96/maxpool2/output.csv
#   inflating: activations/img96/conv3/input.csv
#   inflating: activations/img96/conv3/output.csv
#   inflating: activations/img96/maxpool4/input.csv
#   inflating: activations/img96/maxpool4/output.csv
#   inflating: activations/img96/conv5/input.csv
#   inflating: activations/img96/conv5/output.csv
#   inflating: activations/img96/fc6/input.csv
#   inflating: activations/img96/fc6/output.csv
#   inflating: activations/img96/output/input.csv
#   inflating: activations/img96/output/output.csv
#   inflating: activations/img97/input.csv
#   inflating: activations/img97/output.csv
#   inflating: activations/img97/conv1/input.csv
#   inflating: activations/img97/conv1/output.csv
#   inflating: activations/img97/maxpool2/input.csv
#   inflating: activations/img97/maxpool2/output.csv
#   inflating: activations/img97/conv3/input.csv
#   inflating: activations/img97/conv3/output.csv
#   inflating: activations/img97/maxpool4/input.csv
#   inflating: activations/img97/maxpool4/output.csv
#   inflating: activations/img97/conv5/input.csv
#   inflating: activations/img97/conv5/output.csv
#   inflating: activations/img97/fc6/input.csv
#   inflating: activations/img97/fc6/output.csv
#   inflating: activations/img97/output/input.csv
#   inflating: activations/img97/output/output.csv
#   inflating: activations/img98/input.csv
#   inflating: activations/img98/output.csv
#   inflating: activations/img98/conv1/input.csv
#   inflating: activations/img98/conv1/output.csv
#   inflating: activations/img98/maxpool2/input.csv
#   inflating: activations/img98/maxpool2/output.csv
#   inflating: activations/img98/conv3/input.csv
#   inflating: activations/img98/conv3/output.csv
#   inflating: activations/img98/maxpool4/input.csv
#   inflating: activations/img98/maxpool4/output.csv
#   inflating: activations/img98/conv5/input.csv
#   inflating: activations/img98/conv5/output.csv
#   inflating: activations/img98/fc6/input.csv
#   inflating: activations/img98/fc6/output.csv
#   inflating: activations/img98/output/input.csv
#   inflating: activations/img98/output/output.csv
#   inflating: activations/img99/input.csv
#   inflating: activations/img99/output.csv
#   inflating: activations/img99/conv1/input.csv
#   inflating: activations/img99/conv1/output.csv
#   inflating: activations/img99/maxpool2/input.csv
#   inflating: activations/img99/maxpool2/output.csv
#   inflating: activations/img99/conv3/input.csv
#   inflating: activations/img99/conv3/output.csv
#   inflating: activations/img99/maxpool4/input.csv
#   inflating: activations/img99/maxpool4/output.csv
#   inflating: activations/img99/conv5/input.csv
#   inflating: activations/img99/conv5/output.csv
#   inflating: activations/img99/fc6/input.csv
#   inflating: activations/img99/fc6/output.csv
#   inflating: activations/img99/output/input.csv
#   inflating: activations/img99/output/output.csv

# %%
import unittest

class OpTestCase(unittest.TestCase):

    def setUp(self):
        bit = 32
        self.number_range = (-(2**(bit-1)), 2**(bit-1) - 1)
        self.weightsDict, self.scalesDict = getWeightAndScale()
        self.max_samples = 100 #100


    def tearDown(self):
        self.weightsDict, self.scalesDict = None, None
        self.source = None

    def test_C1(self):
        for i in range(self.max_samples):
            self.source = "./activations/img{}/".format(i)
            x = np.loadtxt(self.source+"/conv1/input.csv", delimiter=',').astype(int)
            x = x.reshape(1, 1, 32, 32)
            x, _ = Conv2d(self.number_range, x, self.weightsDict["conv1.conv"], out_channels=6)
            x = x.flatten()
            x_ = np.loadtxt(self.source+"/conv1/output.csv", delimiter=',').astype(int)
            self.assertTrue(np.all(x == x_))

    def test_ACTQUANT(self):
        for i in range(self.max_samples):
            self.source = "./activations/img{}/".format(i)
            x = np.loadtxt(self.source+"/conv1/output.csv", delimiter=',').astype(int)
            x = ActQuant(x, self.scalesDict["conv1.conv"])
            x = ReLU(x).flatten()
            x_ = np.loadtxt(self.source+"/maxpool2/input.csv", delimiter=',').astype(int)
            self.assertTrue(np.all(x == x_))

    def test_S2(self):
        for i in range(self.max_samples):
            self.source = "./activations/img{}/".format(i)
            x = np.loadtxt(self.source+"/maxpool2/input.csv", delimiter=',').astype(int)
            x = x.reshape(1, 6, 28, 28)
            x = MaxPool2d(x).flatten()
            x_ = np.loadtxt(self.source+"/maxpool2/output.csv", delimiter=',').astype(int)
            self.assertTrue(np.all(x == x_))

    def test_C3(self):
        for i in range(self.max_samples):
            self.source = "./activations/img{}/".format(i)
            x = np.loadtxt(self.source+"/conv3/input.csv", delimiter=',').astype(int)
            x = x.reshape(1, 6, 14, 14)
            x, _ = Conv2d(self.number_range, x, self.weightsDict["conv3.conv"], out_channels=16)
            x = x.flatten()
            x_ = np.loadtxt(self.source+"/conv3/output.csv", delimiter=',').astype(int)
            self.assertTrue(np.all(x == x_))

    def test_S4(self):
        for i in range(self.max_samples):
            self.source = "./activations/img{}/".format(i)
            x = np.loadtxt(self.source+"/maxpool4/input.csv", delimiter=',').astype(int)
            x = x.reshape(1, 16, 10, 10)
            x = MaxPool2d(x).flatten()
            x_ = np.loadtxt(self.source+"/maxpool4/output.csv", delimiter=',').astype(int)
            self.assertTrue(np.all(x == x_))

    def test_C5(self):
        for i in range(self.max_samples):
            self.source = "./activations/img{}/".format(i)
            x = np.loadtxt(self.source+"/conv5/input.csv", delimiter=',').astype(int)
            x = x.reshape(1, 16, 5, 5)
            x, _ = Conv2d(self.number_range, x, self.weightsDict["conv5.conv"], out_channels=120)
            x = x.flatten()
            x_ = np.loadtxt(self.source+"/conv5/output.csv", delimiter=',').astype(int)
            self.assertTrue(np.all(x == x_))

    def test_F6(self):
        for i in range(self.max_samples):
            self.source = "./activations/img{}/".format(i)
            x = np.loadtxt(self.source+"/fc6/input.csv", delimiter=',').astype(int)
            x = x.reshape(1, 120)
            x, _ = Linear(self.number_range, x, self.weightsDict["fc6.fc"])
            x_ = np.loadtxt(self.source+"/fc6/output.csv", delimiter=',')
            self.assertTrue(np.all(x == x_))

    def test_OUTPUT(self):
        for i in range(1,self.max_samples):
            self.source = "./activations/img{}/".format(i)
            x = np.loadtxt(self.source+"/output/input.csv", delimiter=',').astype(int)
            x = x.reshape(1, 84)
            x, _ = Linear(self.number_range, x, self.weightsDict["output.fc"], self.weightsDict["outputBias"])
            x_ = np.loadtxt(self.source+"/output/output.csv", delimiter=',')
            self.assertTrue(np.all(x == x_))

# %%
# tests = ['test_C1']
# suite = unittest.TestSuite(map(OpTestCase, tests))
suite = unittest.TestLoader().loadTestsFromTestCase(OpTestCase)
unittest.TextTestRunner(verbosity=2).run(suite)
# Out:
# test_ACTQUANT (__main__.OpTestCase) ... ok
# test_C1 (__main__.OpTestCase) ... ok
# test_C3 (__main__.OpTestCase) ... ok
# test_C5 (__main__.OpTestCase) ... ok
# test_F6 (__main__.OpTestCase) ... ok
# test_OUTPUT (__main__.OpTestCase) ... ok
# test_S2 (__main__.OpTestCase) ... ok
# test_S4 (__main__.OpTestCase) ... ok
#
# ----------------------------------------------------------------------
# Ran 8 tests in 13.877s
#
# OK
# <unittest.runner.TextTestResult run=8 errors=0 failures=0>

# %% [markdown]
# ### 1.2 Reconstruct the LeNet in HW1
# * Fill in the TODO in `forward()` of `LeNet` in `functional.py`.
# * Test the model with the test dataset. There should be no accuracy degradation if you have done everything correctly.

# %%
def test(model, dataloader: DataLoader, max_samples=None):
    cnt = 0
    total = 0
    n_inferences = 0
    for i, data in enumerate(dataloader):

        images, labels = data[0].numpy(), data[1].numpy()
        y = model.forward(images)

        y = np.argmax(y, axis=1)
        cnt = cnt + np.count_nonzero((labels == y) == True)
        total += images.shape[0]

        if max_samples:
            n_inferences += images.shape[0]
            if n_inferences >= max_samples:
                break

    print("Accuracy: {}%".format(cnt/total*100))
    return cnt/total*100

# %%
transform = transforms.Compose(
    [
     transforms.Resize((32, 32)),
     transforms.ToTensor(),
     transforms.Normalize((0.5,), (0.5,))
    ])

testset = torchvision.datasets.MNIST(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=4,
                                         shuffle=False, num_workers=2)
def run_LeNet(n_bit, max_samples = None):
    number_range = (-(2**(n_bit-1)), 2**(n_bit-1) - 1)
    print("bit:", n_bit)
    print("bit-width range:",number_range)

    psum_range = {
        'c1': number_range,
        'c3': number_range,
        'c5': number_range,
        'f6': number_range,
        'output': number_range
    }

    model = LeNet(psum_range)

    return test(model, testloader)

run_LeNet(n_bit = 32)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 154395264.59it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 68827098.76it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 39931933.33it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 14813785.98it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# bit: 32
# bit-width range: (-2147483648, 2147483647)
# Accuracy: 98.14%
# 98.14

# %% [markdown]
# ## 2. Bit-width of Partial Sums
# ### 2.1 Question: Find the minimum bit-width of partial sums for all layers with the highest accuracy
# 1. Use matplotlib to plot "Test Accuracy(%)" versus "Bit-width of Partial Sums" for "Bit-width of Partial Sums" in $[2, 32]$ by `matplotlib.pyplot.plot()` and put result in the report.
#     * [Plot with matplotlib](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html).
# 2. What is the smallest bit-width of partial sums that maintains the same accuracy from the previous plot?

# %%
import matplotlib.pyplot as plt
acc = []
for i in range(1, 17):
    acc.append(run_LeNet(i*2))

# TODO
plt.plot(range(2,34,2), acc, marker='o', color='blue')
plt.title('Test Accuracy(%)" versus "Bit-width of Partial Sums')
plt.xlabel('Bit-width of Partial Sums')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()
# Out:
# bit: 2
# bit-width range: (-2, 1)
# Accuracy: 11.35%
# bit: 4
# bit-width range: (-8, 7)
# Accuracy: 11.35%
# bit: 6
# bit-width range: (-32, 31)
# Accuracy: 11.35%
# bit: 8
# bit-width range: (-128, 127)
# Accuracy: 11.35%
# bit: 10
# bit-width range: (-512, 511)
# Accuracy: 11.35%
# bit: 12
# bit-width range: (-2048, 2047)
# Accuracy: 11.35%
# bit: 14
# bit-width range: (-8192, 8191)
# Accuracy: 36.26%
# bit: 16
# bit-width range: (-32768, 32767)
# Accuracy: 97.81%
# bit: 18
# bit-width range: (-131072, 131071)
# Accuracy: 98.14%
# bit: 20
# bit-width range: (-524288, 524287)
# Accuracy: 98.14%
# bit: 22
# bit-width range: (-2097152, 2097151)
# Accuracy: 98.14%
# bit: 24
# bit-width range: (-8388608, 8388607)
# Accuracy: 98.14%
# bit: 26
# bit-width range: (-33554432, 33554431)
# Accuracy: 98.14%
# bit: 28
# bit-width range: (-134217728, 134217727)
# Accuracy: 98.14%
# bit: 30
# bit-width range: (-536870912, 536870911)
# Accuracy: 98.14%
# bit: 32
# bit-width range: (-2147483648, 2147483647)
# Accuracy: 98.14%

# %% [markdown]
# ### 2.2 Question: Find the minimum bit-width of partial sums for each layer without hurting the accuracy
# 1. Plot the distribution of partial sums of each quantized layer in the CNN with the MNIST test dataset and put the result in report. Write down the min, max, and standard deviation for each layer.
#     * Check the TODO in `LeNet` of `functional.py`. You should save all partial sums to the dictionary, `psum_record_dict`.
#     * We can get this dictionary after running the model with the first image in the test dataset by `model.psum_record_dict`.
# 2. Determine the minimum bit-width of partial sums in each layer without hurting the accuracy.
#     * Fill in the TODO to see if the accuracy is still the same.
#     * Show the accuracy in the report after doing so.

# %%
import matplotlib.pyplot as plt
n_bit = 32
number_range = (-(2**(n_bit-1)), 2**(n_bit-1) - 1)
print("bit:", n_bit)
print("bit-width range:",number_range)

psum_range = {
    'c1': number_range,
    'c3': number_range,
    'c5': number_range,
    'f6': number_range,
    'output': number_range
}

model = LeNet(psum_range)

image = np.expand_dims(testset[0][0], axis=0)
_ = model.forward(image, psum_record = True)

# TODO
# Plot the distribution of partial sums of each quantized layer in the CNN
conv1_record = model.psum_record_dict['c1']
conv1_record = [int(x.real) for x in conv1_record]
conv3_record = model.psum_record_dict['c3']
conv3_record = [int(x.real) for x in conv3_record]
conv5_record = model.psum_record_dict['c5']
conv5_record = [int(x.real) for x in conv5_record]
fc6_record = model.psum_record_dict['f6']
fc6_record = [int(x.real) for x in fc6_record]
output_record = model.psum_record_dict['output']
output_record = [int(x.real) for x in output_record]
def plot(var, name):
  min_value = np.min(var)
  max_value = np.max(var)
  std_value = np.std(var)
  print (name+"_min_partial_sum = {}".format(min_value))
  print (name+"_max_partial_sum = {}".format(max_value))
  print (name+"_standard deviation_partial_sum = {}".format(std_value))
  plt.hist(var, bins=100, range=None, density=False, facecolor='blue', edgecolor='blue')
  plt.xlabel('partial_sum')
  plt.ylabel('numbers')
  plt.grid(True)
  plt.show()
  print('\n')

plot(conv1_record, 'conv1')
plot(conv3_record, 'conv3')
plot(conv5_record, 'conv5')
plot(fc6_record, 'fc6')
plot(output_record, 'output')
# Out:
# bit: 32
# bit-width range: (-2147483648, 2147483647)
# conv1_min_partial_sum = -65719
# conv1_max_partial_sum = 61119
# conv1_standard deviation_partial_sum = 14695.02059495775
# conv3_min_partial_sum = -86196
# conv3_max_partial_sum = 32701
# conv3_standard deviation_partial_sum = 13685.063595803571
# conv5_min_partial_sum = -22761
# conv5_max_partial_sum = 17345
# conv5_standard deviation_partial_sum = 5278.362709781564
# fc6_min_partial_sum = -22726
# fc6_max_partial_sum = 22931
# fc6_standard deviation_partial_sum = 6814.782848677579
# output_min_partial_sum = -21818
# output_max_partial_sum = 3370
# output_standard deviation_partial_sum = 5364.636346566406

# %%
# TODO
# Test your model with those Bit-widths you choose
def partial_sum_range(name, bit):
  min_range = (-(2**(bit-1)))
  max_range = (2**(bit-1) - 1)
  print(name+'_bits:'+ str(bit))
  print(name+'_range:'+'('+str(min_range)+','+str(max_range)+')')
  return min_range, max_range

conv1_min, conv1_max = partial_sum_range('Conv1', 17)
conv3_min, conv3_max = partial_sum_range('Conv3', 17) #16 is the best 17 is the no change acc
conv5_min, conv5_max = partial_sum_range('Conv5', 15)
fc6_min, fc6_max = partial_sum_range('Fc6', 15)  #14 is the best 15 is the no change acc
output_min, output_max = partial_sum_range('Output', 13)

psum_range = {
    'c1': (conv1_min, conv1_max),
    'c3': (conv3_min, conv3_max),
    'c5': (conv5_min, conv5_max),
    'f6': (fc6_min, fc6_max),
    'output': (output_min, output_max)
}


model = LeNet(psum_range)

_ = test(model, testloader)
# Out:
# Conv1_bits:17
# Conv1_range:(-65536,65535)
# Conv3_bits:17
# Conv3_range:(-65536,65535)
# Conv5_bits:15
# Conv5_range:(-16384,16383)
# Fc6_bits:15
# Fc6_range:(-16384,16383)
# Output_bits:13
# Output_range:(-4096,4095)
# Accuracy: 98.14%

# %% [markdown]
# ## 3. Evaluation: Energy Model
# ### 3.1 Question: Evaluate these two approaches based on the following energy model:
# $$E_w = s_{mul}\times N_{mul} + s_{add}\times N_{add},$$
# $$s_{mul} = \alpha\times \left(\frac{B_{mul}}{8}\right)^2,\ \alpha = 64,$$
# $$s_{add} = \beta\times B_{add}, \ \beta=1,$$
# The variables $N_{mul}$ and $N_{add}$ represent the number of multiplications and additions in your dataflow, respectively. It's possible to calculate the $N_{mul}$ and $N_{add}$ of each layer by hand. The variables $B_{mul}$ and $B_{add}$ denote the bit-widths of multiplier and adder, respectively. The constants α and β are provided to model the energy scaling factor of multiplication and addition, respectively. Additionally, $s_{mul}$ represents the energy cost per multiplication, which is proportional to the square of the multiplier’s bit-width. On the other hand, $s_{add}$ denotes the energy cost per addition, which is linearly proportional to the adder’s bit-width. For instance, in our estimation model, a 4-bit multiplier has an energy cost per multiplication of 16, which is computed as 64 x (4/8)^2.
# * You must accumulate the energy layer by layer to obtain the overall $E_w$, if each layer has a  different $B_{mul}$ or $B_{add}$.
# * We only consider convolution and fully-connected operations, ignoring pooling and ReLU operations in this energy model.
# * Disclaimer: Note that this energy model is artificial and oversimplified. DO NOT apply it to your research work.
#
# 1. Calculate the overall $E_w$ with minimum bit-width for the setup of 2.1.
# 2. Calculate the energy layer by layer and also the overall $E_w$ for the setup of 2.2.
